# %% [markdown]
# # Appendix

# %%
import pandas as pd
df = pd.read_csv('all_labeled_sentences.csv', encoding='utf8')
df['has_citation'].value_counts()
# Out:
# 0.0    211017
# 1.0     31422
# Name: has_citation, dtype: int64

# %%
sample_neg = df[df.has_citation == 0].sample(50, random_state=0)
print('\n===\nExample sentences without citations:')

for i, row in sample_neg.iterrows():
    print('(no citation)', row['text'])
# Out:
# ===
# Example sentences without citations:
# (no citation) how to join these lumber boards is essential to woodworking.
# (no citation) Paper 309
#
# Page 1
#
# CHI 2018 Paper
#
# CHI 2018, April 21­26, 2018, Montréal, QC, Canada
#
# Guided by this prior work, we conducted a study to answer this overarching question: How does socioeconomic context shape caregivers' perceptions and use of current PA tracking tools?
# (no citation) Our system was more accurate on fully incorrect SPSes (57% were "Accurate") than partially incorrect SPSes (36% were "Accurate").
# (no citation) 15.00 DOI: https://doi.org/10.1145/3173574.3173656
#
# INTRODUCTION Electronic textile technology enables people to create expressive, interactive, and functional textile artifacts for both playful and serious applications.
# (no citation) In the long-answer category, recordings coded as Definition made up 7.63%.
# (no citation) Clickstream and in-video dropout data are passively collected in that the data is naturally collected regardless of learners' intention.
# (no citation) Our results (Tab.
# (no citation) Publication date: January 2017.
# (no citation) Paper 156
#
# Page 3
#
# CHI 2018 Paper
#
# CHI 2018, April 21­26, 2018, Montréal, QC, Canada
#
# Figure 2.
# (no citation) are more correlated with total-views than others (obnoxious, unconvincing, confusing etc.).
# (no citation) [u]
# However, though commenters often presented this as common sense, there was also recognition that understanding specific privacy practices requires research.
# (no citation) (P13)
# Finally, the theme of independence was mentioned by four participants--that is, enabling tasks that had previously required assistance from others.
# (no citation) HCI researchers often engage in multiple preliminary or pilot studies in which conditions and methods are progressively tuned to create sensitive experiments that reliably reveal significant effects.
# (no citation) Explicit instructions were given to "feel the sides of the buildings all the way to the base to find the doors".
# (no citation) ACM Classification Keywords H.5.m.
# (no citation) We develop an application using HindSight to warn cyclists of approaching vehicles outside their field of view and evaluate it in an exploratory study with 15 users.
# (no citation) Based on this framework, we implement InfoNice as a Power BI custom visual called "Infographic Designer".
# (no citation) The rendering rule for pitch also behaves similarly.
# (no citation) When riding Ava, limitations of the Körper are easily apparent: after riding any bike for longer periods of time, the legs get tired.
# (no citation) CONCLUSION In this paper, we proposed a method called Ohmic-Touch that extends the modality of touch inputs using the electric resistance on commercial capacitive touch surfaces.
# (no citation) "Can you?"
# (no citation) During reflection, they provided a variety of viewpoints on what they felt about apps' data collection activities and the companies behind them.
# (no citation) Do not place input controls on the bottom right.
# (no citation) We apply this training to our access to large and varied datasets.
# (no citation) After the training tasks, participants did three 5-minute tasks that corresponded to the three conditions (Control, Content-similar, and Curated).
# (no citation) Our application software was developed with Unity.
# (no citation) Mapping patterns to stories was con-
#
# sidered considered less simple but very much possible with
#
# an average rating of 6.8 1
#
# 10.
# (no citation) At Farxad center, Nafiso (F13) drew a static scene depicting a church by assembling blocks on the screen (Figure 5b).
# (no citation) Efficient space use.
# (no citation) Unfortunately, sometimes software can also be unreliable.
# (no citation) This indicates that merely perceiving information transparency was not able to promote users' cognitive control, but it did serve to enhance user trust directly.
# (no citation) In contrast, P5 had little experience with visualization, and compared to learning with graphic design tools: "it takes 30 minutes for me to learn the [Data Illustrator] tutorial via a person, that usually to me is not an easy program.
# (no citation) With respect to the ambulatory setting, we learned that the exergames promoted the reinforcement and reestablishment of family relationships.
# (no citation) Parents should monitor there kids phones but I feel this app is to restrictive.
# (no citation) While our study provides evidence of the utility of our device combination for specific tasks, an in-depth study of open-ended visual exploration (cf.
# (no citation) This is interesting since the confidence interval visualization contains all the information necessary to compute the optimally weighted average--that is, it shows the sensor measurements and their associated variances.
# (no citation) They may be synchronous: daily standup meetings are a
# * - The work was performed while the author was at FXPAL
#
# Paper 170
#
# Page 1
#
# CHI 2018 Paper
#
# CHI 2018, April 21­26, 2018, Montréal, QC, Canada
#
# common practice among software development teams, particularly those who follow an agile process.
# (no citation) Any category with less than 2% representation or that had strong overlap with other categories were combined into other categories or eliminated.
# (no citation) In contrast, explanations of Expert Systems, Bayesian Networks, and Case-Base Reasoning influenced later research on explaining intelligent systems.
# (no citation) Our participants noted that the presence of a role model from a similar community/region as theirs would help them start a dialogue with their parents/partners about their independence and careers.
# (no citation) the pianist found that she was unable to get the system to follow her intended path the technical operator might have responded by nudging her along a particular path anyway (though in this case did not).
# (no citation) Furthermore, human annotators corrected 9,987 cooking actions the NLP tagger mislabeled.
# (no citation) We present this most frequently used frame (N=276, 34%) in more detail as we answer RQ1b.
# (no citation) The `high' level was chosen as the average level for high-level details plus one standard deviation, and likewise `low' was equal to the average for low-level details plus one standard deviation.
# (no citation) · We propose several implications and directions for future research in HCI towards achieving this goal.
# (no citation) CHI 2018, April 21­26, 2018, Montreal, QC, Canada © 2018 Copyright is held by the owner/author(s).
# (no citation) CONCLUSION Our analysis of how shopkeepers coped with demonetization gives descriptive insight into the nature of technology adoption in state-mandated decisions.
# (no citation) Our method focuses specifically on enabling access to diverse content within the music space but this approach is extensible to many other domains.
# (no citation) Sometimes I take the battery with me and charge it while I am at my garden.
# (no citation) Tests of fixed effects in two linear mixed models.

# %%
sample_pos = df[df.has_citation == 1].sample(50, random_state=0)
print('\n===\nExample sentences with citations:')
for i, row in sample_pos.iterrows():
    print('Raw text:', row['text'])
    print(row['has_citation'])
    print('Processed text:', row['processed_text'])
# Out:
# ===
# Example sentences with citations:
# Raw text: These are questions of experience, politics and human values [11,19,79].
# 1.0
# Processed text: These are questions of experience, politics and human values.
# Raw text: 1https://kodi.tv/
#
# Distribution of Head and Gaze Angles We measured the 3D head pose by fitting a generic 3D face model to the detected facial landmarks, and transformed the onscreen gaze location to the 3D direction vector in the camera coordinate system as in [3].
# 1.0
# Processed text: 1https://kodi.tv/
#
# Distribution of Head and Gaze Angles We measured the 3D head pose by fitting a generic 3D face model to the detected facial landmarks, and transformed the onscreen gaze location to the 3D direction vector in the camera coordinate system as in.
# Raw text: Block-Based Programming Interface Block-based programming interfaces are well represented in educational programming games and environments today--with notable examples being Scratch [66], Blockly [16], Reduct [4], BOTS [22], and Tern [26].
# 1.0
# Processed text: Block-Based Programming Interface Block-based programming interfaces are well represented in educational programming games and environments today--with notable examples being Scratch, Blockly, Reduct, BOTS, and Tern.
# Raw text: These behaviors can implicitly communicate power, dominance, and status, as well as social and emotional closeness [10, 28, 29, 52].
# 1.0
# Processed text: These behaviors can implicitly communicate power, dominance, and status, as well as social and emotional closeness.
# Raw text: For these visualizations to be effective, corresponding tools had to provide certain key functionalities such as filtering and clustering the data [21], or adding, removing, and rearranging the dimensions [15, 23].
# 1.0
# Processed text: For these visualizations to be effective, corresponding tools had to provide certain key functionalities such as filtering and clustering the data, or adding, removing, and rearranging the dimensions.
# Raw text: According to the literature, WMC is related to performance of a variety of higher-order cognitive tasks eg, reading comprehension, complex learning, and reasoning [15, 16].
# 1.0
# Processed text: According to the literature, WMC is related to performance of a variety of higher-order cognitive tasks eg, reading comprehension, complex learning, and reasoning.
# Raw text: On Amazon Mechanical Turk, we see workers react to customers posting low-paying tasks (a breach in the earning stake), by breaching their respective quality stake ('you get what you pay for') [40].
# 1.0
# Processed text: On Amazon Mechanical Turk, we see workers react to customers posting low-paying tasks (a breach in the earning stake), by breaching their respective quality stake ('you get what you pay for').
# Raw text: The overall concentration effect, often confounded with "visual tunneling", results in a reduced
#
# sensitivity across the entire visual field including the central concentrated areas [18].
# 1.0
# Processed text: The overall concentration effect, often confounded with "visual tunneling", results in a reduced
#
# sensitivity across the entire visual field including the central concentrated areas.
# Raw text: Similarly, Lohr and Komogortsev [36] compared smooth pursuitbased input against dwell-based input approaches.
# 1.0
# Processed text: Similarly, Lohr and Komogortsev compared smooth pursuitbased input against dwell-based input approaches.
# Raw text: Children's television and videos can provide productive learning opportunities for kids [15] and useful respites from caregiving for adults [24], in addition to serving as an enjoyable part of daily life.
# 1.0
# Processed text: Children's television and videos can provide productive learning opportunities for kids and useful respites from caregiving for adults, in addition to serving as an enjoyable part of daily life.
# Raw text: We chose an even number of steps because people tend to go to the middle of the scale if it has an odd number of points [51], and we had four points because P1 considered it would be difficult for participants to discern 6 or 8 levels of impact.
# 1.0
# Processed text: We chose an even number of steps because people tend to go to the middle of the scale if it has an odd number of points, and we had four points because P1 considered it would be difficult for participants to discern 6 or 8 levels of impact.
# Raw text: In forming links between game elements and experience, the proposed methods ensure that researchers clarify their subjective interpretations of experience, which may be otherwise indistinct (eg, immersion, presence, and flow [8, 45]); greater retention of conceptual consistency and legibility across the literature can be attained as a result.
# 1.0
# Processed text: In forming links between game elements and experience, the proposed methods ensure that researchers clarify their subjective interpretations of experience, which may be otherwise indistinct (eg, immersion, presence, and flow); greater retention of conceptual consistency and legibility across the literature can be attained as a result.
# Raw text: Medhi's research shows that semi-literate and non-literate users prefer text-free user interfaces that are
#
# designed with graphics and voice [40, 41, 42], informing the design of social media, email, and assistive technology for this user group [43, 59, 75].
# 1.0
# Processed text: Medhi's research shows that semi-literate and non-literate users prefer text-free user interfaces that are
#
# designed with graphics and voice, informing the design of social media, email, and assistive technology for this user group.
# Raw text: The (un)Representativeness of Social Media Data Prior work has shown that data sampled from social media are unlikely to be representative of any population other than social media users [33].
# 1.0
# Processed text: The (un)Representativeness of Social Media Data Prior work has shown that data sampled from social media are unlikely to be representative of any population other than social media users.
# Raw text: Pasquero et al investigated tactile output on a smartwatch [23].
# 1.0
# Processed text: Pasquero et al investigated tactile output on a smartwatch.
# Raw text: Instead, we are arguing that NHST is the wrong tool for analysing a swathe of different measures ­ instead, when analysing extensive datasets researchers might consider the estimation approach advocated by Dragicevic [12].
# 1.0
# Processed text: Instead, we are arguing that NHST is the wrong tool for analysing a swathe of different measures ­ instead, when analysing extensive datasets researchers might consider the estimation approach advocated by Dragicevic.
# Raw text: On the positive side, many studies showed that visual images and embodiment of CAs significantly improve users' perception of social presence [44], motivation [3], entertainment [30] and trust [4].
# 1.0
# Processed text: On the positive side, many studies showed that visual images and embodiment of CAs significantly improve users' perception of social presence, motivation, entertainment and trust.
# Raw text: We agree with Ananny and Crawford [7] that asking for transparency--or interpretability--is not enough.
# 1.0
# Processed text: We agree with Ananny and Crawford that asking for transparency--or interpretability--is not enough.
# Raw text: Prior research has found similar results on ridesharing platforms where drivers blamed their low ratings on passengers using inappropriate review rubrics [29].
# 1.0
# Processed text: Prior research has found similar results on ridesharing platforms where drivers blamed their low ratings on passengers using inappropriate review rubrics.
# Raw text: Considering volumetric deformation [17] may improve the motions of fatter characters, and considering biological properties [36] (eg, minimization of muscle actuation energy) may be useful to produce biologically natural motions.
# 1.0
# Processed text: Considering volumetric deformation may improve the motions of fatter characters, and considering biological properties (eg, minimization of muscle actuation energy) may be useful to produce biologically natural motions.
# Raw text: Guo et al [22] performed a study with 26 participants to model touch interactions on a smart phone for improving Web search ranking.
# 1.0
# Processed text: Guo et al performed a study with 26 participants to model touch interactions on a smart phone for improving Web search ranking.
# Raw text: The installations are not seen as the only design resource [16]., but also the existing physical layout and the social practices of the place.
# 1.0
# Processed text: The installations are not seen as the only design resource., but also the existing physical layout and the social practices of the place.
# Raw text: One is a lack of understanding on real-life user experience and attention to the gap between user interactions in the lab and those in the wild [15, 43].
# 1.0
# Processed text: One is a lack of understanding on real-life user experience and attention to the gap between user interactions in the lab and those in the wild.
# Raw text: Many researchers discuss the importance of effectively scaling public participation to address civic challenges, and have introduced novel online technologies to engage the public [44, 74, 82, 90].
# 1.0
# Processed text: Many researchers discuss the importance of effectively scaling public participation to address civic challenges, and have introduced novel online technologies to engage the public.
# Raw text: While Aadhaar and demonetization are comparable in that they have impacted virtually all citizens who participate in the economy, Aadhaar was gradual, and the government spent significant effort in both the organizational and technological aspects of adoption [33].
# 1.0
# Processed text: While Aadhaar and demonetization are comparable in that they have impacted virtually all citizens who participate in the economy, Aadhaar was gradual, and the government spent significant effort in both the organizational and technological aspects of adoption.
# Raw text: We hypothesise that interactive feedforward, in which players identify with the self model while perceiving it as performing at a level they have not previously achieved, will improve performance more
#
# than an unenhanced self model [14, 74, 86].
# 1.0
# Processed text: We hypothesise that interactive feedforward, in which players identify with the self model while perceiving it as performing at a level they have not previously achieved, will improve performance more
#
# than an unenhanced self model.
# Raw text: Doing so may have led them to avoid overly general abstractions of "steering" that ended up less useful (such as the wings of a bird or the rudder of a ship) and towards more targeted analogical inspirations including the twisting of a cardboard box which drove their final design of warping the wings to steer [1].
# 1.0
# Processed text: Doing so may have led them to avoid overly general abstractions of "steering" that ended up less useful (such as the wings of a bird or the rudder of a ship) and towards more targeted analogical inspirations including the twisting of a cardboard box which drove their final design of warping the wings to steer.
# Raw text: A subset of the data used in this paper was used in [21], but here we have a complementary focus on abuser strategies and, consequently, our analysis of the dataset is much different (see the next section).
# 1.0
# Processed text: A subset of the data used in this paper was used in, but here we have a complementary focus on abuser strategies and, consequently, our analysis of the dataset is much different (see the next section).
# Raw text: In behavioural science, structural equation modelling uses statistical methods to analyse relationships that contain unknown variables [49], thereby modelling mechanisms to gain a coherent picture of the relationships.
# 1.0
# Processed text: In behavioural science, structural equation modelling uses statistical methods to analyse relationships that contain unknown variables, thereby modelling mechanisms to gain a coherent picture of the relationships.
# Raw text: The mean Levenshtein distance [44] between entered and corrected word was 1.27.
# 1.0
# Processed text: The mean Levenshtein distance between entered and corrected word was 1.27.
# Raw text: To account for the material's active role in the unfolding of action possibilities, hands-on approaches are privileged over representational approaches [63, 12].
# 1.0
# Processed text: To account for the material's active role in the unfolding of action possibilities, hands-on approaches are privileged over representational approaches.
# Raw text: Commonly used techniques such as graphs have been found effective in communicating numeric information [25,42].
# 1.0
# Processed text: Commonly used techniques such as graphs have been found effective in communicating numeric information.
# Raw text: Researchers and practitioners have developed architecture platforms and applications that present customized user interfaces (eg, a high contrast color scheme) and provide assistive technology (eg, a screen reader) based on a user's profile and selected preferences [55,57].
# 1.0
# Processed text: Researchers and practitioners have developed architecture platforms and applications that present customized user interfaces (eg, a high contrast color scheme) and provide assistive technology (eg, a screen reader) based on a user's profile and selected preferences.
# Raw text: Our study adds to the literature showing that working long stretches is physically and mentally tiring [48].
# 1.0
# Processed text: Our study adds to the literature showing that working long stretches is physically and mentally tiring.
# Raw text: Panoply [32,33] shows that expert principles of cognitive behavioral therapy principles can guide the crowd to provide useful mental health support to others.
# 1.0
# Processed text: Panoply shows that expert principles of cognitive behavioral therapy principles can guide the crowd to provide useful mental health support to others.
# Raw text: These requirements are not well-understood outside of the professional white-collar knowledge work context, where resources are abundant, and therefore are not addressed by popular technology platforms [48, 58].
# 1.0
# Processed text: These requirements are not well-understood outside of the professional white-collar knowledge work context, where resources are abundant, and therefore are not addressed by popular technology platforms.
# Raw text: and (c) events (eg, wars, disasters, protests) [51, 60].
# 1.0
# Processed text: and (c) events (eg, wars, disasters, protests).
# Raw text: As Whittaker [47] points out: little is known about "when and why people keep or delete different types of information."
# 1.0
# Processed text: As Whittaker points out: little is known about "when and why people keep or delete different types of information."
# Raw text: To improve the interaction efficiency with current HWDs, researchers have proposed a number of different input modalities [6,10,23,26], which range from highly noticeable and spatial
# Permission to make digital or hard copies of all or part of this work for personal or classroom use is granted without fee provided that copies are not made or distributed for profit or commercial advantage and that copies bear this notice and the full citation on the first page.
# 1.0
# Processed text: To improve the interaction efficiency with current HWDs, researchers have proposed a number of different input modalities, which range from highly noticeable and spatial
# Permission to make digital or hard copies of all or part of this work for personal or classroom use is granted without fee provided that copies are not made or distributed for profit or commercial advantage and that copies bear this notice and the full citation on the first page.
# Raw text: To improve parameter validity, rigorous likelihood-free inverse modeling methods could be used [34].
# 1.0
# Processed text: To improve parameter validity, rigorous likelihood-free inverse modeling methods could be used.
# Raw text: This result confirms prior work showing that site reputation is an important factor in users' warning decisions [3, 18].
# 1.0
# Processed text: This result confirms prior work showing that site reputation is an important factor in users' warning decisions.
# Raw text: The traditional MPP traversal occurs when HCIRs (Node 1) work with PIOs (Node 2) to generate press releases; Vines et al describe this process in detail [58].
# 1.0
# Processed text: The traditional MPP traversal occurs when HCIRs (Node 1) work with PIOs (Node 2) to generate press releases; Vines et al describe this process in detail.
# Raw text: Paper 381
#
# Page 9
#
# CHI 2018 Honourable Mention
#
# CHI 2018, April 21­26, 2018, Montréal, QC, Canada
#
# News services facilitate the embargo system, yet they also contribute to information overload and are not heavily utilized by journalists, who rely more heavily on social media [24, 28] and take professional pride in their curated relationships with quality sources [38].
# 1.0
# Processed text: Paper 381
#
# Page 9
#
# CHI 2018 Honourable Mention
#
# CHI 2018, April 21­26, 2018, Montréal, QC, Canada
#
# News services facilitate the embargo system, yet they also contribute to information overload and are not heavily utilized by journalists, who rely more heavily on social media and take professional pride in their curated relationships with quality sources.
# Raw text: In fact, Cutrona and Russell [22] identified that coping with a mental illness like depression may need more ES which explains why Mood Disorder communities, that span subreddits like r/depression, offer more ES.
# 1.0
# Processed text: In fact, Cutrona and Russell identified that coping with a mental illness like depression may need more ES which explains why Mood Disorder communities, that span subreddits like r/depression, offer more ES.
# Raw text: As is common in this type of experiment and as suggested by Carney et al [15], we used a cover story to keep our research question hidden from participants.
# 1.0
# Processed text: As is common in this type of experiment and as suggested by Carney et al, we used a cover story to keep our research question hidden from participants.
# Raw text: Individuals can attach negative thoughts or emotions to particular words or sounds due to negative past experiences [15, 39], and this can influence how they approach these in the future.
# 1.0
# Processed text: Individuals can attach negative thoughts or emotions to particular words or sounds due to negative past experiences, and this can influence how they approach these in the future.
# Raw text: It is notable that while work on Rule Extraction remains active, it remains isolated [79].
# 1.0
# Processed text: It is notable that while work on Rule Extraction remains active, it remains isolated.
# Raw text: Sequential triangulation holds the possibility of ensuring a systematically user experience-driven process, where initial findings can be followed up by additional data for further explanation, validation or exploration [18].
# 1.0
# Processed text: Sequential triangulation holds the possibility of ensuring a systematically user experience-driven process, where initial findings can be followed up by additional data for further explanation, validation or exploration.
# Raw text: In HCI, Isenberg and Fisher propose visual cues for group awareness in document queries and searching activities [24].
# 1.0
# Processed text: In HCI, Isenberg and Fisher propose visual cues for group awareness in document queries and searching activities.
# Raw text: As the place, size, and aspect ratios generated in each paper [1, 16] are different, we adjust the size per the extant goal of doubling the original video.
# 1.0
# Processed text: As the place, size, and aspect ratios generated in each paper are different, we adjust the size per the extant goal of doubling the original video.

# %% [markdown]
# ### Data Cleaning
# This section provides a careful walk-through of our data cleaning process. In particular, it focuses on justifying each step and providing examples.
#
# Broadly, there are 4 issues (in order of execution, not importance)
# 1. Tokenizing academic text
# 2. Finding and "disposing" of citations cleanly
# 3. Finding and removing reference sections
# 4. Dealing with artifacts of PDF conversion
#
# #### Tokenizing text from academic PDF files
# Academic text includes frequent use of the period character in ways that are not handled well by NLTK's default sentence tokenizer. Therefore, we simply replace common academic expressions with an equivalent (albeit grammatically incorrect) version without periods.

# %%
from nltk import tokenize

data = "This sentence is quite academic, i.e. it belongs in an academic paper (e.g. a conference paper). \
We show in Fig. 1 that our work is important, which supports the findings of Smith et al. among others."

pairs = {
    'Fig.': 'Fig',
    'e.g.': 'eg',
    'i.e.': 'ie',
    'et al.': 'et al',
}
for key, val in pairs.items():
    data = data.replace(key, val)
sentences = tokenize.sent_tokenize(data)
print(sentences)
# Out:
# ['This sentence is quite academic, ie it belongs in an academic paper (eg a conference paper).', 'We show in Fig 1 that our work is important, which supports the findings of Smith et al among others.']

# %% [markdown]
# #### Finding and "disposing" of citations cleanly
# To even beging generating labels for our machine learning task, we need to generate labels that indicate which sentences have citations. However, if we don't "dispose" of the citation markers in the training data (e.g. bracketed citations like [1] or [34,35]) our training data won't generalize at all to real data. Most obviously, a character-based model might just learn to label all sentences with a bracket character as having citation. However, less obvious issues may occur: for example, we found after stripping away the [1], we might be left with odd-looking text, such as a comma surrounding by whitespace.
#
# `"...Smith et al. showed this [1], and therefore..." -> "Smith et al. showed this , and therefore..."`
#
# #### Finding and removing reference sections
